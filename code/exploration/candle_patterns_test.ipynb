# %%
import sys
sys.path.append("../")
from plotting import CandlePlot
import pandas as pd

# %%
from technicals.patterns import apply_patterns

# %%
df = pd.read_pickle("../data/GBP_JPY_H1.pkl")

# %%
df_an = df[['time', 'mid_o', 'mid_h', 'mid_l', 'mid_c']].copy()

# %%
df_an.tail()
# Out:
#                            time    mid_o    mid_h    mid_l    mid_c
# 37217 2022-12-30 17:00:00+00:00  159.184  159.216  158.402  158.510
# 37218 2022-12-30 18:00:00+00:00  158.512  158.522  157.919  157.935
# 37219 2022-12-30 19:00:00+00:00  157.932  158.240  157.840  158.016
# 37220 2022-12-30 20:00:00+00:00  158.014  158.721  158.014  158.700
# 37221 2022-12-30 21:00:00+00:00  158.704  158.706  158.338  158.578

# %%
df_an = apply_patterns(df_an)

# %%
df_an.tail()
# Out:
#                            time    mid_o    mid_h    mid_l    mid_c  \
# 37217 2022-12-30 17:00:00+00:00  159.184  159.216  158.402  158.510
# 37218 2022-12-30 18:00:00+00:00  158.512  158.522  157.919  157.935
# 37219 2022-12-30 19:00:00+00:00  157.932  158.240  157.840  158.016
# 37220 2022-12-30 20:00:00+00:00  158.014  158.721  158.014  158.700
# 37221 2022-12-30 21:00:00+00:00  158.704  158.706  158.338  158.578
#
#        body_lower  body_upper  body_bottom_perc  body_top_perc  body_perc  \
# 37217     158.510     159.184         13.267813      96.068796  82.800983
# 37218     157.935     158.512          2.653400      98.341625  95.688226
# 37219     157.932     158.016         23.000000      44.000000  21.000000
# 37220     158.014     158.700          0.000000      97.029703  97.029703
# 37221     158.578     158.704         65.217391      99.456522  34.239130
#
#        ...  body_perc_prev_2  HANGING_MAN  SHOOTING_STAR  SPINNING_TOP  \
# 37217  ...         57.235142        False          False         False
# 37218  ...         77.870216        False          False         False
# 37219  ...         82.800983        False          False         False
# 37220  ...         95.688226        False          False         False
# 37221  ...         21.000000        False          False         False
#
#        MARUBOZU  ENGULFING  TWEEZER_TOP  TWEEZER_BOTTOM  MORNING_STAR  \
# 37217     False       True        False           False         False
# 37218     False      False        False           False         False
# 37219     False      False        False           False         False
# 37220     False      False        False           False         False
# 37221     False      False        False           False         False
#
#        EVENING_STAR
# 37217         False
# 37218         False
# 37219         False
# 37220         False
# 37221         False
#
# [5 rows x 31 columns]

# %%
import plotly.graph_objects as go

# %%
df_an[df_an.MARUBOZU==True]
# Out:
#                            time    mid_o    mid_h    mid_l    mid_c  \
# 35    2017-01-10 09:00:00+00:00  140.264  140.906  140.264  140.906
# 889   2017-02-28 23:00:00+00:00  139.660  139.995  139.660  139.990
# 1268  2017-03-22 17:00:00+00:00  138.590  138.590  138.238  138.239
# 2757  2017-06-16 18:00:00+00:00  141.750  141.750  141.643  141.645
# 2893  2017-06-26 10:00:00+00:00  141.981  142.258  141.978  142.258
# ...                         ...      ...      ...      ...      ...
# 35790 2022-10-07 05:00:00+00:00  161.772  162.041  161.772  162.039
# 35926 2022-10-16 21:00:00+00:00  166.983  166.983  166.568  166.575
# 36241 2022-11-03 00:00:00+00:00  168.356  168.356  167.883  167.892
# 36370 2022-11-10 10:00:00+00:00  166.430  166.917  166.422  166.916
# 37047 2022-12-20 15:00:00+00:00  160.906  160.906  159.466  159.493
#
#        body_lower  body_upper  body_bottom_perc  body_top_perc   body_perc  \
# 35        140.264     140.906          0.000000     100.000000  100.000000
# 889       139.660     139.990          0.000000      98.507463   98.507463
# 1268      138.239     138.590          0.284091     100.000000   99.715909
# 2757      141.645     141.750          1.869159     100.000000   98.130841
# 2893      141.981     142.258          1.071429     100.000000   98.928571
# ...           ...         ...               ...            ...         ...
# 35790     161.772     162.039          0.000000      99.256506   99.256506
# 35926     166.575     166.983          1.686747     100.000000   98.313253
# 36241     167.892     168.356          1.902748     100.000000   98.097252
# 36370     166.430     166.916          1.616162      99.797980   98.181818
# 37047     159.493     160.906          1.875000     100.000000   98.125000
#
#        ...  body_perc_prev_2  HANGING_MAN  SHOOTING_STAR  SPINNING_TOP  \
# 35     ...         44.875346        False          False         False
# 889    ...         44.052045        False          False         False
# 1268   ...         65.886288        False          False         False
# 2757   ...         38.888889        False          False         False
# 2893   ...         30.215827        False          False         False
# ...    ...               ...          ...            ...           ...
# 35790  ...         51.636364        False          False         False
# 35926  ...         30.534351        False          False         False
# 36241  ...         29.491525        False          False         False
# 36370  ...          4.477612        False          False         False
# 37047  ...         60.030166        False          False         False
#
#        MARUBOZU  ENGULFING  TWEEZER_TOP  TWEEZER_BOTTOM  MORNING_STAR  \
# 35         True       True        False           False         False
# 889        True      False        False           False         False
# 1268       True       True        False           False         False
# 2757       True       True        False           False         False
# 2893       True      False        False           False         False
# ...         ...        ...          ...             ...           ...
# 35790      True       True        False           False         False
# 35926      True       True        False           False         False
# 36241      True      False        False           False         False
# 36370      True       True        False           False         False
# 37047      True       True        False           False         False
#
#        EVENING_STAR
# 35            False
# 889           False
# 1268          False
# 2757          False
# 2893          False
# ...             ...
# 35790         False
# 35926         False
# 36241         False
# 36370         False
# 37047         False
#
# [94 rows x 31 columns]

# %%
MARKER = '#0066FF'
dfp = df_an.iloc[-200:]
cp = CandlePlot(dfp, candles=True)
df_temp = cp.df_plot[cp.df_plot.MARUBOZU==True]
cp.fig.add_trace(go.Candlestick(
                x=df_temp.sTime,
                open=df_temp.mid_o,
                high=df_temp.mid_h,
                low=df_temp.mid_l,
                close=df_temp.mid_c,
                line=dict(width=1), opacity=1,
                increasing_fillcolor=MARKER,
                decreasing_fillcolor=MARKER,
                increasing_line_color=MARKER,  
                decreasing_line_color=MARKER
            ))

cp.show_plot()
